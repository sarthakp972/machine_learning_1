# %% [markdown]
# <a href="https://colab.research.google.com/github/sarthakp972/machine_learning_1/blob/main/basic_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/content/drive/MyDrive/ML/Book1.csv")

# %%
df1= pd.read_csv("/content/drive/MyDrive/ML/Automobile_data.csv")

# %%
df1
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of    Area  House  amount        status
# 0  1000      1   10000     furnished
# 1   900      2   50000  wellfrnushed
# 2  2000      3   40000   unfurnished
# 3  1000      4   10000     furnished>

# %%
df.shape
# Out:
# (4, 4)

# %%
df.tail(2
        )
# Out:
#    Area  House  amount       status
# 2  2000      3   40000  unfurnished
# 3  1000      4   10000    furnished

# %%
df.isnull().sum()
# Out:
# Area      0
# House     0
# amount    0
# status    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Area    4 non-null      int64
#  1   House   4 non-null      int64
#  2   amount  4 non-null      int64
#  3   status  4 non-null      object
# dtypes: int64(3), object(1)
# memory usage: 256.0+ bytes

# %%
status_values_counts=df['status'].value_counts()
status_values_counts
# Out:
# furnished       2
# wellfrnushed    1
# unfurnished     1
# Name: status, dtype: int64

# %%
status_values_counts.index
# Out:
# Index(['furnished', 'wellfrnushed', 'unfurnished'], dtype='object')

# %%
plt.bar(status_values_counts.index,status_values_counts)
plt.show()

# %%
bar_colours=['orange','green','red']
plt.bar(status_values_counts.index,status_values_counts,color=bar_colours)
plt.show()

# %%
size=[2,1,1]
label=['furnished', 'wellfrnushed', 'unfurnished']
plt.pie(size,labels=label, autopct='%1.2f%%')
plt.show()

# %%
bar_colours=['orange','green','red']
plt.show()

# %%
df1
.isnull().sum()
# Out:
#   File "<ipython-input-45-e259264f47b4>", line 2
#     .isnull().sum()
#     ^
# SyntaxError: invalid syntax

# %%
df1.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df1
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...
